# %%
# %pip install pymupdf gender-guesser spacy pandas matplotlib jinja2
# Out:
# Collecting pymupdf
#   Using cached pymupdf-1.26.3-cp39-abi3-win_amd64.whl.metadata (3.4 kB)
# Collecting gender-guesser
#   Using cached gender_guesser-0.4.0-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting spacy
#   Using cached spacy-3.8.7-cp313-cp313-win_amd64.whl.metadata (28 kB)
# Collecting pandas
#   Downloading pandas-2.3.0-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.3-cp313-cp313-win_amd64.whl.metadata (11 kB)
# Collecting jinja2
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy)
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy)
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy)
#   Using cached murmurhash-1.0.13-cp313-cp313-win_amd64.whl.metadata (2.2 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy)
#   Using cached cymem-2.0.11-cp313-cp313-win_amd64.whl.metadata (8.8 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy)
#   Using cached preshed-3.0.10-cp313-cp313-win_amd64.whl.metadata (2.5 kB)
# Collecting thinc<8.4.0,>=8.3.4 (from spacy)
#   Using cached thinc-8.3.6-cp313-cp313-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy)
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy)
#   Using cached srsly-2.5.1-cp313-cp313-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.5.0,>=0.1.0 (from spacy)
#   Using cached weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting typer<1.0.0,>=0.3.0 (from spacy)
#   Downloading typer-0.16.0-py3-none-any.whl.metadata (15 kB)
# Collecting tqdm<5.0.0,>=4.38.0 (from spacy)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting numpy>=1.19.0 (from spacy)
#   Downloading numpy-2.3.1-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting requests<3.0.0,>=2.13.0 (from spacy)
#   Using cached requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 (from spacy)
#   Using cached pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Requirement already satisfied: setuptools in d:\softwares\anaconda3\envs\biasbuster\lib\site-packages (from spacy) (78.1.1)
# Requirement already satisfied: packaging>=20.0 in d:\softwares\anaconda3\envs\biasbuster\lib\site-packages (from spacy) (25.0)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy)
#   Using cached langcodes-3.5.0-py3-none-any.whl.metadata (29 kB)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy)
#   Using cached language_data-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Downloading pydantic_core-2.33.2-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in d:\softwares\anaconda3\envs\biasbuster\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.14.0)
# Collecting typing-inspection>=0.4.0 (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3.0.0,>=2.13.0->spacy)
#   Downloading charset_normalizer-3.4.2-cp313-cp313-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.13.0->spacy)
#   Using cached certifi-2025.6.15-py3-none-any.whl.metadata (2.4 kB)
# Collecting blis<1.4.0,>=1.3.0 (from thinc<8.4.0,>=8.3.4->spacy)
#   Using cached blis-1.3.0-cp313-cp313-win_amd64.whl.metadata (7.6 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.4.0,>=8.3.4->spacy)
#   Using cached confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: colorama in d:\softwares\anaconda3\envs\biasbuster\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Collecting click>=8.0.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Using cached click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting shellingham>=1.3.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=10.11.0 (from typer<1.0.0,>=0.3.0->spacy)
#   Downloading rich-14.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting cloudpathlib<1.0.0,>=0.7.0 (from weasel<0.5.0,>=0.1.0->spacy)
#   Using cached cloudpathlib-0.21.1-py3-none-any.whl.metadata (14 kB)
# Collecting smart-open<8.0.0,>=5.2.1 (from weasel<0.5.0,>=0.1.0->spacy)
#   Using cached smart_open-7.3.0-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy)
#   Downloading wrapt-1.17.2-cp313-cp313-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\softwares\anaconda3\envs\biasbuster\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.58.4-cp313-cp313-win_amd64.whl.metadata (108 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-11.3.0-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting MarkupSafe>=2.0 (from jinja2)
#   Downloading MarkupSafe-3.0.2-cp313-cp313-win_amd64.whl.metadata (4.1 kB)
# Collecting marisa-trie>=1.1.0 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy)
#   Using cached marisa_trie-1.2.1-cp313-cp313-win_amd64.whl.metadata (9.3 kB)
# Requirement already satisfied: six>=1.5 in d:\softwares\anaconda3\envs\biasbuster\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting markdown-it-py>=2.2.0 (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\softwares\anaconda3\envs\biasbuster\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.2)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached pymupdf-1.26.3-cp39-abi3-win_amd64.whl (18.7 MB)
# Using cached gender_guesser-0.4.0-py2.py3-none-any.whl (379 kB)
# Using cached spacy-3.8.7-cp313-cp313-win_amd64.whl (13.9 MB)
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Using cached cymem-2.0.11-cp313-cp313-win_amd64.whl (39 kB)
# Using cached langcodes-3.5.0-py3-none-any.whl (182 kB)
# Using cached murmurhash-1.0.13-cp313-cp313-win_amd64.whl (24 kB)
# Using cached preshed-3.0.10-cp313-cp313-win_amd64.whl (115 kB)
# Using cached pydantic-2.11.7-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp313-cp313-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ------------------------------------- -- 1.8/2.0 MB 10.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 8.9 MB/s eta 0:00:00
# Using cached requests-2.32.4-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.2-cp313-cp313-win_amd64.whl (105 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Using cached srsly-2.5.1-cp313-cp313-win_amd64.whl (630 kB)
# Using cached thinc-8.3.6-cp313-cp313-win_amd64.whl (1.7 MB)
# Using cached blis-1.3.0-cp313-cp313-win_amd64.whl (6.3 MB)
# Using cached confection-0.1.5-py3-none-any.whl (35 kB)
# Downloading numpy-2.3.1-cp313-cp313-win_amd64.whl (12.7 MB)
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    ------- -------------------------------- 2.4/12.7 MB 12.6 MB/s eta 0:00:01
#    ------------------ --------------------- 5.8/12.7 MB 13.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.6/12.7 MB 12.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.4/12.7 MB 11.0 MB/s eta 0:00:01
#    ------------------------------------ --- 11.5/12.7 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.7/12.7 MB 10.4 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typer-0.16.0-py3-none-any.whl (46 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Using cached weasel-0.4.1-py3-none-any.whl (50 kB)
# Using cached cloudpathlib-0.21.1-py3-none-any.whl (52 kB)
# Using cached smart_open-7.3.0-py3-none-any.whl (61 kB)
# Downloading pandas-2.3.0-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ------ --------------------------------- 1.8/11.0 MB 9.8 MB/s eta 0:00:01
#    -------------- ------------------------- 3.9/11.0 MB 10.0 MB/s eta 0:00:01
#    -------------------- ------------------- 5.5/11.0 MB 9.0 MB/s eta 0:00:01
#    ------------------------- -------------- 7.1/11.0 MB 9.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.7/11.0 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 9.1 MB/s eta 0:00:00
# Downloading matplotlib-3.10.3-cp313-cp313-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ------- -------------------------------- 1.6/8.1 MB 7.8 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.4/8.1 MB 8.5 MB/s eta 0:00:01
#    ------------------------- -------------- 5.2/8.1 MB 8.5 MB/s eta 0:00:01
#    --------------------------------- ------ 6.8/8.1 MB 8.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 8.5 MB/s eta 0:00:00
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached certifi-2025.6.15-py3-none-any.whl (157 kB)
# Using cached click-8.2.1-py3-none-any.whl (102 kB)
# Downloading contourpy-1.3.2-cp313-cp313-win_amd64.whl (223 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.58.4-cp313-cp313-win_amd64.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 11.4 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.8-cp313-cp313-win_amd64.whl (71 kB)
# Using cached language_data-1.3.0-py3-none-any.whl (5.4 MB)
# Using cached marisa_trie-1.2.1-cp313-cp313-win_amd64.whl (149 kB)
# Downloading MarkupSafe-3.0.2-cp313-cp313-win_amd64.whl (15 kB)
# Downloading pillow-11.3.0-cp313-cp313-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    --------------- ------------------------ 2.6/7.0 MB 12.5 MB/s eta 0:00:01
#    --------------------------------- ------ 5.8/7.0 MB 14.1 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 14.2 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading rich-14.0.0-py3-none-any.whl (243 kB)
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading wrapt-1.17.2-cp313-cp313-win_amd64.whl (38 kB)
# Installing collected packages: pytz, gender-guesser, cymem, wrapt, wasabi, urllib3, tzdata, typing-inspection, tqdm, spacy-loggers, spacy-legacy, shellingham, pyparsing, pymupdf, pydantic-core, pillow, numpy, murmurhash, mdurl, MarkupSafe, marisa-trie, kiwisolver, idna, fonttools, cycler, cloudpathlib, click, charset_normalizer, certifi, catalogue, annotated-types, srsly, smart-open, requests, pydantic, preshed, pandas, markdown-it-py, language-data, jinja2, contourpy, blis, rich, matplotlib, langcodes, confection, typer, thinc, weasel, spacy
#
#    ----------------------------------------  0/50 [pytz]
#    ---- -----------------------------------  5/50 [urllib3]
#    ---- -----------------------------------  6/50 [tzdata]
#    ------ ---------------------------------  8/50 [tqdm]
#    --------- ------------------------------ 12/50 [pyparsing]
#    ---------- ----------------------------- 13/50 [pymupdf]
#    ---------- ----------------------------- 13/50 [pymupdf]
#    ---------- ----------------------------- 13/50 [pymupdf]
#    ------------ --------------------------- 15/50 [pillow]
#    ------------ --------------------------- 15/50 [pillow]
#    ------------ --------------------------- 16/50 [numpy]
#    ------------ --------------------------- 16/50 [numpy]
#    ------------ --------------------------- 16/50 [numpy]
#    ------------ --------------------------- 16/50 [numpy]
#    ------------ --------------------------- 16/50 [numpy]
#    ------------ --------------------------- 16/50 [numpy]
#    ------------ --------------------------- 16/50 [numpy]
#    ------------ --------------------------- 16/50 [numpy]
#    ------------ --------------------------- 16/50 [numpy]
#    ------------ --------------------------- 16/50 [numpy]
#    ------------ --------------------------- 16/50 [numpy]
#    ------------ --------------------------- 16/50 [numpy]
#    ------------ --------------------------- 16/50 [numpy]
#    ----------------- ---------------------- 22/50 [idna]
#    ------------------ --------------------- 23/50 [fonttools]
#    ------------------ --------------------- 23/50 [fonttools]
#    ------------------ --------------------- 23/50 [fonttools]
#    ------------------ --------------------- 23/50 [fonttools]
#    ------------------ --------------------- 23/50 [fonttools]
#    ------------------ --------------------- 23/50 [fonttools]
#    ------------------ --------------------- 23/50 [fonttools]
#    -------------------- ------------------- 26/50 [click]
#    ------------------------ --------------- 31/50 [srsly]
#    ------------------------ --------------- 31/50 [srsly]
#    ------------------------ --------------- 31/50 [srsly]
#    --------------------------- ------------ 34/50 [pydantic]
#    --------------------------- ------------ 34/50 [pydantic]
#    --------------------------- ------------ 34/50 [pydantic]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ---------------------------- ----------- 36/50 [pandas]
#    ----------------------------- ---------- 37/50 [markdown-it-py]
#    ------------------------------ --------- 38/50 [language-data]
#    ------------------------------ --------- 38/50 [language-data]
#    ------------------------------ --------- 38/50 [language-data]
#    ------------------------------ --------- 38/50 [language-data]
#    ------------------------------- -------- 39/50 [jinja2]
#    -------------------------------- ------- 41/50 [blis]
#    --------------------------------- ------ 42/50 [rich]
#    ---------------------------------- ----- 43/50 [matplotlib]
#    ---------------------------------- ----- 43/50 [matplotlib]
#    ---------------------------------- ----- 43/50 [matplotlib]
#    ---------------------------------- ----- 43/50 [matplotlib]
#    ---------------------------------- ----- 43/50 [matplotlib]
#    ---------------------------------- ----- 43/50 [matplotlib]
#    ---------------------------------- ----- 43/50 [matplotlib]
#    ---------------------------------- ----- 43/50 [matplotlib]
#    ---------------------------------- ----- 43/50 [matplotlib]
#    ---------------------------------- ----- 43/50 [matplotlib]
#    ---------------------------------- ----- 43/50 [matplotlib]
#    ------------------------------------ --- 46/50 [typer]
#    ------------------------------------- -- 47/50 [thinc]
#    ------------------------------------- -- 47/50 [thinc]
#    -------------------------------------- - 48/50 [weasel]
#    ---------------------------------------  49/50 [spacy]
#    ---------------------------------------  49/50 [spacy]
#    ---------------------------------------  49/50 [spacy]
#    ---------------------------------------  49/50 [spacy]
#    ---------------------------------------  49/50 [spacy]
#    ---------------------------------------  49/50 [spacy]
#    ---------------------------------------  49/50 [spacy]
#    ---------------------------------------  49/50 [spacy]
#    ---------------------------------------  49/50 [spacy]
#    ---------------------------------------  49/50 [spacy]
#    ---------------------------------------  49/50 [spacy]
#    ---------------------------------------  49/50 [spacy]
#    ---------------------------------------  49/50 [spacy]
#    ---------------------------------------- 50/50 [spacy]
#
# Successfully installed MarkupSafe-3.0.2 annotated-types-0.7.0 blis-1.3.0 catalogue-2.0.10 certifi-2025.6.15 charset_normalizer-3.4.2 click-8.2.1 cloudpathlib-0.21.1 confection-0.1.5 contourpy-1.3.2 cycler-0.12.1 cymem-2.0.11 fonttools-4.58.4 gender-guesser-0.4.0 idna-3.10 jinja2-3.1.6 kiwisolver-1.4.8 langcodes-3.5.0 language-data-1.3.0 marisa-trie-1.2.1 markdown-it-py-3.0.0 matplotlib-3.10.3 mdurl-0.1.2 murmurhash-1.0.13 numpy-2.3.1 pandas-2.3.0 pillow-11.3.0 preshed-3.0.10 pydantic-2.11.7 pydantic-core-2.33.2 pymupdf-1.26.3 pyparsing-3.2.3 pytz-2025.2 requests-2.32.4 rich-14.0.0 shellingham-1.5.4 smart-open-7.3.0 spacy-3.8.7 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.1 thinc-8.3.6 tqdm-4.67.1 typer-0.16.0 typing-inspection-0.4.1 tzdata-2025.2 urllib3-2.5.0 wasabi-1.1.3 weasel-0.4.1 wrapt-1.17.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy.cli
spacy.cli.download("en_core_web_sm")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import os
import fitz  # PyMuPDF
import re
import spacy
import pandas as pd
from gender_guesser.detector import Detector

# Load spaCy and gender detector
nlp = spacy.load("en_core_web_sm")
gender_detector = Detector()

# %%
def extract_script_text(pdf_path):
    with fitz.open(pdf_path) as doc:
        return "\n".join([page.get_text() for page in doc])

def load_scripts_from_folder(folder_path):
    scripts = {}
    for filename in os.listdir(folder_path):
        if filename.endswith(".pdf"):
            title = filename.replace('.pdf', '')
            text = extract_script_text(os.path.join(folder_path, filename))
            scripts[title] = text
    return scripts

# Update path to your local folder
scripts = load_scripts_from_folder("scripts-data/")
print(f"✅ Loaded {len(scripts)} scripts.")
# Out:
# ✅ Loaded 13 scripts.

# %%
def extract_intro_lines(text):
    lines = text.split('\n')
    clean_lines = []

    for line in lines:
        line = line.strip()
        if 5 < len(line.split()) < 30:
            if not line.isupper() and not re.match(r'^[A-Z]+:$', line):
                clean_lines.append(line)
    return clean_lines

# %%
def detect_character_and_gender(line):
    doc = nlp(line)
    for ent in doc.ents:
        if ent.label_ == "PERSON":
            name = ent.text
            gender = gender_detector.get_gender(name.split()[0])
            return name, gender
    return None, None

# %%
clean_data = []

for title, text in scripts.items():
    lines = extract_intro_lines(text)
    for line in lines:
        character, gender = detect_character_and_gender(line)
        if character and gender in ['male', 'female']:
            clean_data.append({
                "script": title,
                "year": None,  # optional: fill manually later
                "character": character,
                "gender": gender,
                "line": line.strip()
            })

df_cleaned = pd.DataFrame(clean_data)
df_cleaned.to_csv("cleaned_script_data.csv", index=False)
print("✅ Saved cleaned data to cleaned_script_data.csv")
df_cleaned.head()
# Out:
# ✅ Saved cleaned data to cleaned_script_data.csv
#    script  year character  gender  \
# 0  Haider  None    Shiraz    male
# 1  Haider  None   Ghazala  female
# 2  Haider  None   Ghazala  female
# 3  Haider  None   Ghazala  female
# 4  Haider  None   Ghazala  female
#
#                                                 line
# 0                detained at the Shiraz cinema camp…
# 1  Ghazala sees the soldier raising the barricade...
# 2  Surgical instruments are boiling in a pot. Gha...
# 3  silent, Ghazala has a sense of paranoia in her...
# 4  in with a bunch of other surgical tools in a t...
